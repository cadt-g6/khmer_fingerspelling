# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('../assets/framed/lightweight/consonants/ba/39.jpg')

fig, axes = plt.subplots(figsize = (10, 10))

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
axes.imshow(image)

plt.grid()
plt.show()

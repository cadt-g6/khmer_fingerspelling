# %% [markdown]
# # Crop Consonants

# %%
import cv2
import os
import pathlib

# %%
consonants_path = '/Volumes/SD Card/cleaned_lightweight/consonants'
destination_path = '/Volumes/SD Card/cropped/consonants'

# %%
def write(
    width_start,
    width_end,
    height_start,
    height_end,
    destination_path,
    consonant,
    variant,
    image,
    id,
):
    cropped_image = image[width_start:width_end,
                          height_start:height_end]

    name, extension = variant.split('.')
    parent_path = f"{destination_path}/{consonant}"

    filename = f"{name}-{id}.{extension}"
    filepath = f"{parent_path}/{filename}"

    pathlib.Path(parent_path).mkdir(parents=True, exist_ok=True)
    cv2.imwrite(filepath, cropped_image)

# %%
", ".join(os.listdir(consonants_path))
# Out:
# 'ba, cha, chha, chho, cho, da, do, ha, ka, kha, kho, ko, la, lo, mo, na, ngo, nho, no, or, pha, pho, po, ro, sa, ta, tha1, tha2, tho1, tho2, to, vo, yo'

# %%
", ".join(os.listdir(f"{consonants_path}/chho"))
# Out:
# '103.jpg, 227.jpg, 255.jpg, 422.jpg, 494.jpg, 559.jpg, 590.jpg, 635.jpg'

# %%
size = 500
only_run_these = [
    # "ba",
    # "cha"
    # "chha"
    "chho"
]

# y:y+h, x:x+w
positions = {
    "ba": {
        "49.jpg": [f"{50}:{50 + size}", f"{780}:{780 + size}"],
        "134.jpg": [f"{210}:{210 + size}", f"{550}:{550 + size}"],
        "224.jpg": [f"{120}:{120 + size}", f"{650}:{650 + size}"],
        "290.jpg": [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        "374.jpg": [f"{200}:{200 + size}", f"{600}:{600 + size}"],
        "472.jpg": [f"{200}:{200 + size}", f"{600}:{600 + size}"],
        "498.jpg": [f"{50}:{50 + size}", f"{400}:{400 + size}"],
        "527.jpg": [f"{0}:{0 + size}", f"{200}:{200 + size}"],
    },
    "cha": {
        '47.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '219.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '347.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '430.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '524.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '555.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '648.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "chha": {
        '49.jpg': [f"{75}:{75 + size}", f"{425}:{425 + size}"],
        '136.jpg': [f"{80}:{80 + size}", f"{680}:{680 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{280}:{280 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{75}:{75 + size}", f"{350}:{350 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "chho": {
        '103.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '227.jpg': [f"{200}:{200 + size}", f"{600}:{600 + size}"],
        '255.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '422.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '494.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '559.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '590.jpg': [f"{100}:{100 + size}", f"{500}:{500 + size}"],
        '635.jpg': [f"{50}:{50 + size}", f"{350}:{350 + size}"],
    },
    "cho": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "da": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "do": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "ha": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "ka": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "kha": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "kho": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "ko": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "la": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "lo": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "mo": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "na": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "ngo": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "nho": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "no": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "or": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "pha": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "pho": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "po": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "ro": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "sa": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "ta": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "tha1": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "tha2": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "tho1": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "tho2": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "to": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "vo": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
    "yo": {
        '49.jpg': [f"{150}:{150 + size}", f"{400}:{400 + size}"],
        '136.jpg': [f"{150}:{150 + size}", f"{650}:{650 + size}"],
        '233.jpg': [f"{150}:{150 + size}", f"{675}:{675 + size}"],
        '284.jpg': [f"{200}:{200 + size}", f"{780}:{780 + size}"],
        '351.jpg': [f"{200}:{200 + size}", f"{650}:{650 + size}"],
        '432.jpg': [f"{0}:{0 + size}", f"{500}:{500 + size}"],
        '465.jpg': [f"{0}:{0 + size}", f"{400}:{400 + size}"],
        '552.jpg': [f"{100}:{100 + size}", f"{600}:{600 + size}"],
    },
}

len(positions.keys())
# Out:
# 33

# %%
for consonant in positions.keys():
    variants_path = f"{consonants_path}/{consonant}"

    if consonant not in only_run_these:
        continue

    for variant in os.listdir(variants_path):
        print(f"{variants_path}/{variant}")

        position = positions.get(consonant, {}).get(variant, [])

        width = position[0].split(":")
        height = position[1].split(":")

        width_start, width_end = int(width[0]), int(width[1])
        height_start, height_end = int(height[0]), int(height[1])

        image = cv2.imread(f"{variants_path}/{variant}")

        # 1
        write(
            width_start, width_end, height_start, height_end, destination_path,
            consonant, variant, image, "1"
        )

        # 2
        # write(
        #     width_start, width_end, height_start, height_end, destination_path,
        #     consonant, variant, image, "2"
        # )
# Out:
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/103.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/227.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/255.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/422.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/494.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/559.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/590.jpg
# /Volumes/SD Card/cleaned_lightweight/consonants/chho/635.jpg
